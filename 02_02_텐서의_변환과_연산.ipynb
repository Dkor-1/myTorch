# %% [markdown]
# <a href="https://colab.research.google.com/github/Dkor-1/myTorch/blob/main/02_02_%ED%85%90%EC%84%9C%EC%9D%98_%EB%B3%80%ED%99%98%EA%B3%BC_%EC%97%B0%EC%82%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import torch

# %%
tensor = torch.ones(2, 2)

# %%
np_array = tensor.numpy()
np_array
# Out:
# array([[1., 1.],
#        [1., 1.]], dtype=float32)

# %%
np_array2 = np.array(tensor)
np_array2
# Out:
# /var/folders/q8/4d2895412ql0wfqsb19srbvh0000gn/T/ipykernel_25346/2454444564.py:1: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   np_array2 = np.array(tensor)
# array([[1., 1.],
#        [1., 1.]], dtype=float32)

# %%
tensor[0, 0] = -1

# %%
print(f'numpy() result\n{np_array}\n')
print(f'np.array() result\n{np_array2}')
# Out:
# numpy() result
# [[-1.  1.]
#  [ 1.  1.]]
#
# np.array() result
# [[1. 1.]
#  [1. 1.]]

# %%
a = torch.tensor([[1, 2],
                  [3, 4]])
b = torch.tensor([[1, 1],
                  [2, 2]])

# %%
a + b
# Out:
# tensor([[2, 3],
#         [5, 6]])

# %%
torch.add(a, b)
# Out:
# tensor([[2, 3],
#         [5, 6]])

# %%
a * b
# Out:
# tensor([[1, 2],
#         [6, 8]])

# %%
torch.multiply(a, b)
# Out:
# tensor([[1, 2],
#         [6, 8]])

# %%
a = torch.tensor(
    [
        [1, 2],
        [3, 4],
        [5, 6],
        [7, 8],
    ]
)
b = torch.tensor(
    [
        [1, 0, 0],
        [0, 0, 1],
        [1, 1, 0],
    ]
)

print(f'a의 열 개수: {a.shape[1]}')
print(f'b의 행 개수: {b.shape[0]}')
# Out:
# a의 열 개수: 2
# b의 행 개수: 3

# %%
torch.matmul(a, b)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 torch.matmul(a, b)
#
# RuntimeError: mat1 and mat2 shapes cannot be multiplied (4x2 and 3x3)

# %%
a = torch.tensor(
    [
        [1, 2],
        [3, 4],
        [5, 6],
        [7, 8],
    ]
)
b = torch.tensor(
    [
        [1, 0, 0],
        [0, 0, 1],
    ]
)

print(f'a의 열 개수: {a.shape[1]}')
print(f'b의 행 개수: {b.shape[0]}')
# Out:
# a의 열 개수: 2
# b의 행 개수: 2

# %%
torch.matmul(a, b)
# Out:
# tensor([[1, 0, 2],
#         [3, 0, 4],
#         [5, 0, 6],
#         [7, 0, 8]])

# %%
a @ b
# Out:
# tensor([[1, 0, 2],
#         [3, 0, 4],
#         [5, 0, 6],
#         [7, 0, 8]])

# %%
tensor_int = torch.tensor([1, 2], dtype=torch.int32)
tensor_float = torch.tensor([3, 4], dtype=torch.float32)

add_result = tensor_int + tensor_float
mul_result = tensor_int * tensor_float

print(add_result)
print(mul_result)
# Out:
# tensor([4., 6.])
# tensor([3., 8.])

# %%
print(add_result.dtype)
print(mul_result.dtype)
# Out:
# torch.float32
# torch.float32

# %%
tensor_int = torch.tensor([1, 2], dtype=torch.int32)
tensor_float = torch.tensor(
    [
        [3, 1],
        [1, 4]
    ],
    dtype=torch.float32
)

torch.matmul(tensor_int, tensor_float)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[19], line 10
#       1 tensor_int = torch.tensor([1, 2], dtype=torch.int32)
#       2 tensor_float = torch.tensor(
#       3     [
#       4         [3, 1],
#    (...)      7     dtype=torch.float32
#       8 )
# ---> 10 torch.matmul(tensor_int, tensor_float)
#
# RuntimeError: expected m1 and m2 to have the same dtype, but got: int != float

# %%
tensor_cast = tensor_int.to(torch.float32)

torch.matmul(tensor_cast, tensor_float)
# Out:
# tensor([5., 9.])

# %%
tensor = torch.tensor([3, 5, 7, 9, 10])

# %%
tensor[0]
# Out:
# tensor(3)

# %%
tensor[2]
# Out:
# tensor(7)

# %%
tensor[-1]
# Out:
# tensor(10)

# %%
tensor[::2]
# Out:
# tensor([ 3,  7, 10])

# %%
tensor_2d = torch.tensor(
    [
        [1, 3, 5, 7, 9],
        [2, 4, 6, 8, 10],
    ]
)

# %%
tensor_2d[0, :3]
# Out:
# tensor([1, 3, 5])

# %%
tensor_2d[0, 3:]
# Out:
# tensor([7, 9])

# %%
tensor_2d[:, 1:4]
# Out:
# tensor([[3, 5, 7],
#         [4, 6, 8]])
